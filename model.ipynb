# %%
import numpy as np
import pandas as pd

# %%
train_df = pd.read_csv('train.csv')
train_df_copy = train_df.copy()
train_df.head()
# Out:
#   country  year    uniqueid bank_account location_type cellphone_access  \
# 0   Kenya  2018  uniqueid_1          Yes         Rural              Yes
# 1   Kenya  2018  uniqueid_2           No         Rural               No
# 2   Kenya  2018  uniqueid_3          Yes         Urban              Yes
# 3   Kenya  2018  uniqueid_4           No         Rural              Yes
# 4   Kenya  2018  uniqueid_5           No         Urban               No
#
#    household_size  age_of_respondent gender_of_respondent  \
# 0               3                 24               Female
# 1               5                 70               Female
# 2               5                 26                 Male
# 3               5                 34               Female
# 4               8                 26                 Male
#
#   relationship_with_head           marital_status  \
# 0                 Spouse  Married/Living together
# 1      Head of Household                  Widowed
# ...

# %%
train_df.shape
# Out:
# (23524, 13)

# %%
train_df.isnull().sum()
# Out:
# country                   0
# year                      0
# uniqueid                  0
# bank_account              0
# location_type             0
# cellphone_access          0
# household_size            0
# age_of_respondent         0
# gender_of_respondent      0
# relationship_with_head    0
# marital_status            0
# education_level           0
# job_type                  0
# dtype: int64

# %%
test_df = pd.read_csv('test.csv')
test_df_copy = test_df.copy()
test_df.head()
# Out:
#   country  year       uniqueid location_type cellphone_access  household_size  \
# 0   Kenya  2018  uniqueid_6056         Urban              Yes               3
# 1   Kenya  2018  uniqueid_6060         Urban              Yes               7
# 2   Kenya  2018  uniqueid_6065         Rural               No               3
# 3   Kenya  2018  uniqueid_6072         Rural               No               6
# 4   Kenya  2018  uniqueid_6073         Urban               No               3
#
#    age_of_respondent gender_of_respondent relationship_with_head  \
# 0                 30                 Male      Head of Household
# 1                 51                 Male      Head of Household
# 2                 77               Female                 Parent
# 3                 39               Female      Head of Household
# 4                 16                 Male                  Child
#
#             marital_status                  education_level  \
# ...

# %%
test_df.isnull().sum()
# Out:
# country                   0
# year                      0
# uniqueid                  0
# location_type             0
# cellphone_access          0
# household_size            0
# age_of_respondent         0
# gender_of_respondent      0
# relationship_with_head    0
# marital_status            0
# education_level           0
# job_type                  0
# dtype: int64

# %%
test_df.shape
# Out:
# (10086, 12)

# %%
# test_id = test_df.uniqueid
# y = train_df.bank_account

# %%
# from sklearn.preprocessing import LabelEncoder

# Encoder = LabelEncoder()
# encoded_y = y.apply(Encoder.fit_transform)

# %%
# print(test_df_copy.columns)
train_df_copy = train_df_copy.drop(columns=['bank_account','uniqueid'])
test_df_copy = test_df_copy.drop(columns=['uniqueid'])
datas = [train_df_copy, test_df_copy]
df_copy = pd.concat(datas, keys=['x','y'], sort=True)

# %%
test_df_copy.shape
# Out:
# (10086, 11)

# %%
cat_col = []
for i in df_copy.columns:
    if df_copy[i].dtype == 'O':
        cat_col.append(i)
    else:
        pass
    
cat_col
# Out:
# ['cellphone_access',
#  'country',
#  'education_level',
#  'gender_of_respondent',
#  'job_type',
#  'location_type',
#  'marital_status',
#  'relationship_with_head']

# %%
# trying one hot for whole col
df_copy = pd.get_dummies(df_copy, columns=cat_col)
df_copy.head()
# Out:
#      age_of_respondent  household_size  year  cellphone_access_No  \
# x 0                 24               3  2018                    0
#   1                 70               5  2018                    1
#   2                 26               5  2018                    0
#   3                 34               5  2018                    0
#   4                 26               8  2018                    1
#
#      cellphone_access_Yes  country_Kenya  country_Rwanda  country_Tanzania  \
# x 0                     1              1               0                 0
#   1                     0              1               0                 0
#   2                     1              1               0                 0
#   3                     1              1               0                 0
#   4                     0              1               0                 0
#
#      country_Uganda  education_level_No formal education  ...  \
# ...

# %%
train_df_copy = df_copy.loc['x']
test_df_copy = df_copy.loc['y']

# %%
train_df_copy.head()
# Out:
#    age_of_respondent  household_size  year  cellphone_access_No  \
# 0                 24               3  2018                    0
# 1                 70               5  2018                    1
# 2                 26               5  2018                    0
# 3                 34               5  2018                    0
# 4                 26               8  2018                    1
#
#    cellphone_access_Yes  country_Kenya  country_Rwanda  country_Tanzania  \
# 0                     1              1               0                 0
# 1                     0              1               0                 0
# 2                     1              1               0                 0
# 3                     1              1               0                 0
# 4                     0              1               0                 0
#
#    country_Uganda  education_level_No formal education  ...  \
# 0               0                                    0  ...
# ...

# %%
y = train_df.bank_account

# %%
# label encode the target column
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()
encoded_y = encoder.fit_transform(y)
encoded_y = pd.DataFrame(encoded_y)

# %%
X = train_df_copy.iloc[:,:]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, encoded_y, test_size=0.3, random_state=0)

# %%
from xgboost import XGBClassifier

cls = XGBClassifier()
model = cls.fit(X_train, y_train)
# Out:
# C:\Users\SAMUEL PC\Anaconda\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\SAMUEL PC\Anaconda\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
pred = model.predict(test_df_copy)

# %%
score = 1- (cls.score(X, encoded_y))
score
# Out:
# 0.10993028396531201

# %%
predictions = model.predict(test_df_copy)

# %%
train_df_copy2 = train_df.drop(columns=['bank_account','uniqueid'])
test_df_copy2 = test_df.drop(columns=['uniqueid'])
datas = [train_df_copy2, test_df_copy2]
df_copy2 = pd.concat(datas, keys=['x','y'], sort=True)

# %%
# Get number of unique entries in each column with categorical data
object_unique = list(map(lambda col: df_copy2[col].nunique(), cat_col))
d = dict(zip(cat_col, object_unique))

# Print number of unique entries by column, in ascending order
# sorted(d.items(), key=lambda x: x[1])
d.items()
# Out:
# dict_items([('cellphone_access', 2), ('country', 4), ('education_level', 6), ('gender_of_respondent', 2), ('job_type', 10), ('location_type', 2), ('marital_status', 5), ('relationship_with_head', 6)])

# %%
# Columns that will be one-hot encoded
one_hot_encode = ['country', 'gender_of_respondent', 'education_level', 'gender_of_respondent','job_type','location_type',
                 'marital_status', 'relationship_with_head']

# Columns that will be dropped from the dataset
label_encode = ['cellphone_access', ]

# %%
OH_encoder = OneHotEncoder(handle_unknown='ignore', sparse=False)
encoded_df = pd.DataFrame(OH_encoder.fit_transform(df_copy2[one_hot_encode]))

# One-hot encoding removed index; put it back
encoded_df.index = df_copy2.index

# Remove categorical columns (will replace with one-hot encoding)
df_copy2 = df_copy2.drop(cat_col, axis=1)

# Add one-hot encoded columns to numerical features
new_df = pd.concat([df_copy2, encoded_df], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-119-3f210bcbc03b> in <module>()
#       1 OH_encoder = OneHotEncoder(handle_unknown='ignore', sparse=False)
# ----> 2 encoded_df = pd.DataFrame(OH_encoder.fit_transform(df_copy2[one_hot_encode]))
#       3
#       4 # One-hot encoding removed index; put it back
#       5 encoded_df.index = df_copy2.index
#
# ~\Anaconda\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2999             if is_iterator(key):
#    3000                 key = list(key)
# -> 3001             indexer = self.loc._convert_to_indexer(key, axis=1, raise_missing=True)
#    3002
#    3003         # take() does not accept boolean indexers
#
# ~\Anaconda\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
# ...

# %%
df_copy2.head()
# Out:
#      age_of_respondent  household_size  year
# x 0                 24               3  2018
#   1                 70               5  2018
#   2                 26               5  2018
#   3                 34               5  2018
#   4                 26               8  2018

# %%
submission_df = pd.DataFrame({"uniqueid": test_df["uniqueid"] + " x " + test_df["country"], "bank_account": pred})

submission_df.to_csv("submession05.csv",index=False)
